# %% [markdown]
# # Training a ConvNet PyTorch
#
# In this notebook, you'll learn how to use the powerful PyTorch framework to specify a conv net architecture and train it on the human action recognition dataset.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import DataLoader,sampler,Dataset
import torchvision.datasets as dset
import torchvision.transforms as T
import timeit
from PIL import Image
import os
import numpy as np
import scipy.io
import torchsummary as summary

# %% [markdown]
# ## What's this PyTorch business?
#
# * When using a framework like PyTorch or TensorFlow you can harness the power of the GPU for your own custom neural network architectures without having to write CUDA code directly.
# * this notebook will walk you through much of what you need to do to train models using pytorch. if you want to learn more or need further clarification on topics that aren't fully explained here, here are 2 good Pytorch tutorials. 1): http://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html 2)http://pytorch.org/tutorials/beginner/pytorch_with_examples.html
# * It's not necessary to have a GPU for this homework, using a GPU can make your code run faster.

# %% [markdown]
# ## Load Datasets
#
# In this part, we will load the action recognition dataset for the neural network. In order to load data from our custom dataset, we need to write a custom Dataloader. If you put q3_2_data.mat, /valClips,/trainClips,/testClips under the folder of ./data/ , you do not need to change anything in this part.

# %% [markdown]
# First, load the labels of the dataset, you should write your path of the q3_2_data.mat file.

# %%
label_mat=scipy.io.loadmat('./data/hw6_data.mat')
label_train=label_mat['trLb']
print(len(label_train))
label_val=label_mat['valLb']
print(len(label_val))
# Out:
# 7770
# 2230

# %% [markdown]
# ### Dataset class
#
# torch.utils.data.Dataset is an abstract class representing a dataset. The custom dataset should inherit Dataset and override the following methods:
#
#     __len__ so that len(dataset) returns the size of the dataset.
#     __getitem__ to support the indexing such that dataset[i] can be used to get ith sample
#
# Let’s create a dataset class for our action recognition dataset. We will read images in __getitem__. This is memory efficient because all the images are not stored in the memory at once but read as required.
#
# Sample of our dataset will be a dict {'image':image,'img_path':img_path,'Label':Label}. Our datset will take an optional argument transform so that any required processing can be applied on the sample.

# %%
class ActionDataset(Dataset):
    """Action dataset."""

    def __init__(self,  root_dir,labels=[], transform=None):
        """
        Args:
            root_dir (string): Directory with all the images.
            labels(list): labels if images.
            transform (callable, optional): Optional transform to be applied on a sample.
        """
        self.root_dir = root_dir
        self.transform = transform
        self.length=len(os.listdir(self.root_dir))
        self.labels=labels
    def __len__(self):
        return self.length*3

    def __getitem__(self, idx):
        
        folder=int(idx/3)+1
        imidx=idx%3+1
        folder=format(folder,'05d')
        imgname=str(imidx)+'.jpg'
        img_path = os.path.join(self.root_dir,
                                folder,imgname)
        image = Image.open(img_path)
        if len(self.labels)!=0:
            Label=self.labels[int(idx/3)][0]-1
        if self.transform:
            image = self.transform(image)
        if len(self.labels)!=0:
            sample={'image':image,'img_path':img_path,'Label':Label}
        else:
            sample={'image':image,'img_path':img_path}
        return sample

# %% [markdown]
# Iterating over the dataset by a for loop.

# %%
image_dataset=ActionDataset(root_dir='./data/trainClips/',\
                            labels=label_train,transform=T.ToTensor())

#iterating though the dataset
for i in range(10):
    sample=image_dataset[i]
    print(sample['image'].shape)
    print(sample['Label'])
    print(sample['img_path'])
# Out:
# torch.Size([3, 64, 64])
# 0.0
# ./data/trainClips/00001\1.jpg
# torch.Size([3, 64, 64])
# 0.0
# ./data/trainClips/00001\2.jpg
# torch.Size([3, 64, 64])
# 0.0
# ./data/trainClips/00001\3.jpg
# torch.Size([3, 64, 64])
# 0.0
# ./data/trainClips/00002\1.jpg
# torch.Size([3, 64, 64])
# 0.0
# ./data/trainClips/00002\2.jpg
# torch.Size([3, 64, 64])
# 0.0
# ./data/trainClips/00002\3.jpg
# torch.Size([3, 64, 64])
# 0.0
# ./data/trainClips/00003\1.jpg
# torch.Size([3, 64, 64])
# 0.0
# ./data/trainClips/00003\2.jpg
# torch.Size([3, 64, 64])
# 0.0
# ./data/trainClips/00003\3.jpg
# torch.Size([3, 64, 64])
# 0.0
# ./data/trainClips/00004\1.jpg

# %% [markdown]
# We can iterate over the created dataset with a 'for' loop as before. However, we are losing a lot of features by using a simple for loop to iterate over the data. In particular, we are missing out on:
#
# * Batching the data
# * Shuffling the data
# * Load the data in parallel using multiprocessing workers.
#
# torch.utils.data.DataLoader is an iterator which provides all these features.

# %%
image_dataloader = DataLoader(image_dataset, batch_size=4,
                        shuffle=True, num_workers=0)


for i,sample in enumerate(image_dataloader):
    sample['image']=sample['image']
    print(i,sample['image'].shape,sample['img_path'],sample['Label'])
    if i>20: 
        break
# Out:
# 0 torch.Size([4, 3, 64, 64]) ['./data/trainClips/03021\\2.jpg', './data/trainClips/05276\\1.jpg', './data/trainClips/03393\\3.jpg', './data/trainClips/02606\\1.jpg'] tensor([3., 6., 3., 2.], dtype=torch.float64)
# 1 torch.Size([4, 3, 64, 64]) ['./data/trainClips/05508\\1.jpg', './data/trainClips/04193\\3.jpg', './data/trainClips/07604\\1.jpg', './data/trainClips/04796\\2.jpg'] tensor([6., 5., 9., 5.], dtype=torch.float64)
# 2 torch.Size([4, 3, 64, 64]) ['./data/trainClips/03515\\1.jpg', './data/trainClips/00868\\2.jpg', './data/trainClips/06706\\2.jpg', './data/trainClips/01331\\2.jpg'] tensor([3., 0., 8., 1.], dtype=torch.float64)
# 3 torch.Size([4, 3, 64, 64]) ['./data/trainClips/00429\\3.jpg', './data/trainClips/07371\\2.jpg', './data/trainClips/01634\\2.jpg', './data/trainClips/07515\\1.jpg'] tensor([0., 9., 1., 9.], dtype=torch.float64)
# 4 torch.Size([4, 3, 64, 64]) ['./data/trainClips/07531\\1.jpg', './data/trainClips/07111\\2.jpg', './data/trainClips/00230\\3.jpg', './data/trainClips/02915\\3.jpg'] tensor([9., 8., 0., 3.], dtype=torch.float64)
# 5 torch.Size([4, 3, 64, 64]) ['./data/trainClips/06188\\3.jpg', './data/trainClips/05069\\2.jpg', './data/trainClips/00042\\1.jpg', './data/trainClips/03457\\3.jpg'] tensor([7., 6., 0., 3.], dtype=torch.float64)
# 6 torch.Size([4, 3, 64, 64]) ['./data/trainClips/03202\\1.jpg', './data/trainClips/02364\\1.jpg', './data/trainClips/03489\\1.jpg', './data/trainClips/06813\\1.jpg'] tensor([3., 2., 3., 8.], dtype=torch.float64)
# 7 torch.Size([4, 3, 64, 64]) ['./data/trainClips/01345\\3.jpg', './data/trainClips/03789\\1.jpg', './data/trainClips/06362\\2.jpg', './data/trainClips/01476\\3.jpg'] tensor([1., 4., 7., 1.], dtype=torch.float64)
# 8 torch.Size([4, 3, 64, 64]) ['./data/trainClips/07614\\1.jpg', './data/trainClips/03735\\3.jpg', './data/trainClips/07484\\1.jpg', './data/trainClips/03139\\1.jpg'] tensor([9., 4., 9., 3.], dtype=torch.float64)
# 9 torch.Size([4, 3, 64, 64]) ['./data/trainClips/00200\\3.jpg', './data/trainClips/03610\\3.jpg', './data/trainClips/02152\\1.jpg', './data/trainClips/05568\\2.jpg'] tensor([0., 4., 2., 6.], dtype=torch.float64)
# 10 torch.Size([4, 3, 64, 64]) ['./data/trainClips/00448\\1.jpg', './data/trainClips/02660\\2.jpg', './data/trainClips/05941\\2.jpg', './data/trainClips/06190\\3.jpg'] tensor([0., 2., 7., 7.], dtype=torch.float64)
# 11 torch.Size([4, 3, 64, 64]) ['./data/trainClips/06428\\2.jpg', './data/trainClips/02995\\3.jpg', './data/trainClips/02788\\2.jpg', './data/trainClips/02776\\1.jpg'] tensor([7., 3., 3., 3.], dtype=torch.float64)
# 12 torch.Size([4, 3, 64, 64]) ['./data/trainClips/00030\\1.jpg', './data/trainClips/04297\\3.jpg', './data/trainClips/07724\\2.jpg', './data/trainClips/01334\\2.jpg'] tensor([0., 5., 9., 1.], dtype=torch.float64)
# 13 torch.Size([4, 3, 64, 64]) ['./data/trainClips/07252\\3.jpg', './data/trainClips/05057\\1.jpg', './data/trainClips/03454\\1.jpg', './data/trainClips/03365\\2.jpg'] tensor([9., 6., 3., 3.], dtype=torch.float64)
# 14 torch.Size([4, 3, 64, 64]) ['./data/trainClips/05779\\2.jpg', './data/trainClips/03212\\3.jpg', './data/trainClips/07704\\1.jpg', './data/trainClips/01226\\3.jpg'] tensor([7., 3., 9., 1.], dtype=torch.float64)
# 15 torch.Size([4, 3, 64, 64]) ['./data/trainClips/05611\\3.jpg', './data/trainClips/03138\\1.jpg', './data/trainClips/07139\\3.jpg', './data/trainClips/01384\\2.jpg'] tensor([6., 3., 9., 1.], dtype=torch.float64)
# 16 torch.Size([4, 3, 64, 64]) ['./data/trainClips/05376\\3.jpg', './data/trainClips/01423\\2.jpg', './data/trainClips/00999\\2.jpg', './data/trainClips/01842\\2.jpg'] tensor([6., 1., 1., 2.], dtype=torch.float64)
# 17 torch.Size([4, 3, 64, 64]) ['./data/trainClips/01191\\3.jpg', './data/trainClips/06486\\2.jpg', './data/trainClips/03820\\2.jpg', './data/trainClips/01214\\3.jpg'] tensor([1., 8., 4., 1.], dtype=torch.float64)
# 18 torch.Size([4, 3, 64, 64]) ['./data/trainClips/05132\\1.jpg', './data/trainClips/05484\\3.jpg', './data/trainClips/04588\\3.jpg', './data/trainClips/01947\\1.jpg'] tensor([6., 6., 5., 2.], dtype=torch.float64)
# 19 torch.Size([4, 3, 64, 64]) ['./data/trainClips/02687\\1.jpg', './data/trainClips/07091\\2.jpg', './data/trainClips/06195\\3.jpg', './data/trainClips/03341\\3.jpg'] tensor([3., 8., 7., 3.], dtype=torch.float64)
# 20 torch.Size([4, 3, 64, 64]) ['./data/trainClips/05907\\2.jpg', './data/trainClips/02228\\1.jpg', './data/trainClips/01242\\2.jpg', './data/trainClips/05591\\2.jpg'] tensor([7., 2., 1., 6.], dtype=torch.float64)
# 21 torch.Size([4, 3, 64, 64]) ['./data/trainClips/05445\\2.jpg', './data/trainClips/02015\\2.jpg', './data/trainClips/04378\\2.jpg', './data/trainClips/05738\\2.jpg'] tensor([6., 2., 5., 7.], dtype=torch.float64)

# %% [markdown]
# Dataloaders for the training, validationg and testing set.

# %%
image_dataset_train=ActionDataset(root_dir='./data/trainClips/',labels=label_train,transform=T.ToTensor())

image_dataloader_train = DataLoader(image_dataset_train, batch_size=32,
                        shuffle=True, num_workers=0)
image_dataset_val=ActionDataset(root_dir='./data/valClips/',labels=label_val,transform=T.ToTensor())

image_dataloader_val = DataLoader(image_dataset_val, batch_size=32,
                        shuffle=False, num_workers=0)
image_dataset_test=ActionDataset(root_dir='./data/testClips/',labels=[],transform=T.ToTensor())

image_dataloader_test = DataLoader(image_dataset_test, batch_size=32,
                        shuffle=False, num_workers=0)

# %%
dtype = torch.FloatTensor # the CPU datatype
# Constant to control how frequently we print train loss
print_every = 100
# This is a little utility that we'll use to reset the model
# if we want to re-initialize all our parameters
def reset(m):
    if hasattr(m, 'reset_parameters'):
        m.reset_parameters()

# %% [markdown]
# ## Example Model
#
# ### Some assorted tidbits
#
# Let's start by looking at a simple model. First, note that PyTorch operates on Tensors, which are n-dimensional arrays functionally analogous to numpy's ndarrays, with the additional feature that they can be used for computations on GPUs.
#
# We'll provide you with a Flatten function, which we explain here. Remember that our image data (and more relevantly, our intermediate feature maps) are initially N x C x H x W, where:
# * N is the number of datapoints
# * C is the number of image channels.
# * H is the height of the intermediate feature map in pixels
# * W is the height of the intermediate feature map in pixels
#
# This is the right way to represent the data when we are doing something like a 2D convolution, that needs spatial understanding of where the intermediate features are relative to each other. When we input  data into fully connected affine layers, however, we want each datapoint to be represented by a single vector -- it's no longer useful to segregate the different channels, rows, and columns of the data. So, we use a "Flatten" operation to collapse the C x H x W values per representation into a single long vector. The Flatten function below first reads in the N, C, H, and W values from a given batch of data, and then returns a "view" of that data. "View" is analogous to numpy's "reshape" method: it reshapes x's dimensions to be N x ??, where ?? is allowed to be anything (in this case, it will be C x H x W, but we don't need to specify that explicitly).

# %%
class Flatten(nn.Module):
    def forward(self, x):
        N, C, H, W = x.size() # read in N, C, H, W
        return x.view(N, -1)  # "flatten" the C * H * W values into a single vector per image

# %% [markdown]
# ### The example model itself
#
# The first step to training your own model is defining its architecture.
#
# Here's an example of a convolutional neural network defined in PyTorch -- try to understand what each line is doing, remembering that each layer is composed upon the previous layer. We haven't trained anything yet - that'll come next - for now, we want you to understand how everything gets set up.  nn.Sequential is a container which applies each layer
# one after the other.
#
# In this example, you see 2D convolutional layers (Conv2d), ReLU activations, and fully-connected layers (Linear). You also see the Cross-Entropy loss function, and the Adam optimizer being used.
#
# Make sure you understand why the parameters of the Linear layer are 10092 and 10.

# %%
# Here's where we define the architecture of the model... 
simple_model = nn.Sequential(
                nn.Conv2d(3, 32, kernel_size=7, stride=2),
                nn.ReLU(inplace=True),
                Flatten(), # see above for explanation
                nn.Linear(26912, 10), # affine layer
              )

# Set the type of all data in this model to be FloatTensor 
simple_model.type(dtype)

loss_fn = nn.CrossEntropyLoss().type(dtype)
optimizer = optim.Adam(simple_model.parameters(), lr=1e-2) # lr sets the learning rate of the optimizer

# %%
from torchsummary import summary
summary(simple_model,(3,64,64))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 29, 29]           4,736
#               ReLU-2           [-1, 32, 29, 29]               0
#            Flatten-3                [-1, 26912]               0
#             Linear-4                   [-1, 10]         269,130
# ================================================================
# Total params: 273,866
# Trainable params: 273,866
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 0.62
# Params size (MB): 1.04
# Estimated Total Size (MB): 1.71
# ----------------------------------------------------------------

# %% [markdown]
# PyTorch supports many other layer types, loss functions, and optimizers - you will experiment with these next. Here's the official API documentation for these (if any of the parameters used above were unclear, this resource will also be helpful).
#
# * Layers: http://pytorch.org/docs/nn.html
# * Activations: http://pytorch.org/docs/nn.html#non-linear-activations
# * Loss functions: http://pytorch.org/docs/nn.html#loss-functions
# * Optimizers: http://pytorch.org/docs/optim.html#algorithms

# %% [markdown]
# ## Training a specific model
#
# In this section, we're going to specify a model for you to construct. The goal here isn't to get good performance (that'll be next), but instead to get comfortable with understanding the PyTorch documentation and configuring your own model.
#
# Using the code provided above as guidance, and using the following PyTorch documentation, specify a model with the following architecture:
#
# * 7x7 Convolutional Layer with 8 filters and stride of 1
# * ReLU Activation Layer
# * 2x2 Max Pooling layer with a stride of 2
# * 7x7 Convolutional Layer with 16 filters and stride of 1
# * ReLU Activation Layer
# * 2x2 Max Pooling layer with a stride of 2
# * Flatten the feature map
# * ReLU Activation Layer
# * Affine layer to map input units to 10 outputs, you need to figure out the input size here.

# %%
fixed_model_base = nn.Sequential( 
    #########1st TODO  (5 points)###################
                   nn.Conv2d(3, 8, kernel_size=7, stride=1),
                    nn.ReLU(inplace=True),
                    nn.MaxPool2d(kernel_size=2, stride=2),
                    nn.Conv2d(8, 16, kernel_size=7, stride=1),
                    nn.ReLU(inplace=True),
                    nn.MaxPool2d(kernel_size=2, stride=2),
                    Flatten(),
                    nn.ReLU(inplace=True),
                    nn.Linear(1936,10)
    ####################################
            )
fixed_model = fixed_model_base.type(dtype)

summary(fixed_model,(3,64,64))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 8, 58, 58]           1,184
#               ReLU-2            [-1, 8, 58, 58]               0
#          MaxPool2d-3            [-1, 8, 29, 29]               0
#             Conv2d-4           [-1, 16, 23, 23]           6,288
#               ReLU-5           [-1, 16, 23, 23]               0
#          MaxPool2d-6           [-1, 16, 11, 11]               0
#            Flatten-7                 [-1, 1936]               0
#               ReLU-8                 [-1, 1936]               0
#             Linear-9                   [-1, 10]          19,370
# ================================================================
# Total params: 26,842
# Trainable params: 26,842
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 0.64
# Params size (MB): 0.10
# Estimated Total Size (MB): 0.78
# ----------------------------------------------------------------

# %% [markdown]
# To make sure you're doing the right thing, use the following tool to check the dimensionality of your output (it should be 32 x 10, since our batches have size 32 and the output of the final affine layer should be 10, corresponding to our 10 classes):

# %%
## Now we're going to feed a random batch into the model you defined and make sure the output is the right size
x = torch.randn(32, 3, 64, 64).type(dtype)
x_var = Variable(x.type(dtype)) # Construct a PyTorch Variable out of your input data
ans = fixed_model(x_var)        # Feed it through the model! 

# Check to make sure what comes out of your model
# is the right dimensionality... this should be True
# if you've done everything correctly
print(np.array(ans.size()))
np.array_equal(np.array(ans.size()), np.array([32, 10]))
# Out:
# [32 10]
# True

# %% [markdown]
# ### Train the model.
#
# Now that you've seen how to define a model and do a single forward pass of some data through it, let's  walk through how you'd actually train one whole epoch over your training data (using the fixed_model_base we provided above).
#
# Make sure you understand how each PyTorch function used below corresponds to what you implemented in your custom neural network implementation.
#
# Note that because we are not resetting the weights anywhere below, if you run the cell multiple times, you are effectively training multiple epochs (so your performance should improve).
#
# First, set up an RMSprop optimizer (using a 1e-4 learning rate) and a cross-entropy loss function:

# %%
################ 2nd TODO  (5 points)##################
# optimizer = None
# loss_fn = None
loss_fn = nn.CrossEntropyLoss().type(dtype)
optimizer = optim.RMSprop(fixed_model_base.parameters(), lr=1e-4)

# %%
# This sets the model in "training" mode. 
# This is relevant for some layers that may have different behavior
# in training mode vs testing mode, such as Dropout and BatchNorm. 
fixed_model.train()

# Load one batch at a time.
for t, sample in enumerate(image_dataloader_train):
    x_var = Variable(sample['image'])
    #print(type(x_var.data))
    #print(x_var.shape)
    y_var = Variable(sample['Label']).long()

    # This is the forward pass: predict the scores for each class, for each x in the batch.
    scores = fixed_model(x_var)
    
    # Use the correct y values and the predicted y values to compute the loss.
    loss = loss_fn(scores, y_var)
    
    if (t + 1) % print_every == 0:
        print('t = %d, loss = %.4f' % (t + 1, loss.data[0]))

    # Zero out all of the gradients for the variables which the optimizer will update.
    optimizer.zero_grad()
    
    # This is the backwards pass: compute the gradient of the loss with respect to each 
    # parameter of the model.
    loss.backward()
    
    # Actually update the parameters of the model using the gradients computed by the backwards pass.
    optimizer.step()
# Out:
# C:\Users\Abhay Goyal\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# t = 100, loss = 1.7492
# t = 200, loss = 1.6238
# t = 300, loss = 1.5757
# t = 400, loss = 1.2967
# t = 500, loss = 1.5616
# t = 600, loss = 1.0757
# t = 700, loss = 1.2244

# %% [markdown]
# Now you've seen how the training process works in PyTorch. To save you writing boilerplate code, we're providing the following helper functions to help you train for multiple epochs and check the accuracy of your model:

# %%
def train(model, loss_fn, optimizer, dataloader, num_epochs = 4):
    for epoch in range(num_epochs):
        print('Starting epoch %d / %d' % (epoch + 1, num_epochs))
        model.train()
        for t, sample in enumerate(dataloader):
            x_var = Variable(sample['image'])
            y_var = Variable(sample['Label'].long())

            scores = model(x_var)
            
            loss = loss_fn(scores, y_var)
            if (t + 1) % print_every == 0:
                print('t = %d, loss = %.4f' % (t + 1, loss.data[0]))

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

def check_accuracy(model, loader):
    '''
    if loader.dataset.train:
        print('Checking accuracy on validation set')
    else:
        print('Checking accuracy on test set')  
    '''
    num_correct = 0
    num_samples = 0
    model.eval() # Put the model in test mode (the opposite of model.train(), essentially)
    for t, sample in enumerate(loader):
        x_var = Variable(sample['image'])
        y_var = sample['Label']
        #y_var=y_var.cpu()
        scores = model(x_var)
        _, preds = scores.data.max(1)#scores.data.cpu().max(1)
        #print(preds)
        #print(y_var)
        num_correct += (preds.numpy() == y_var.numpy()).sum()
        num_samples += preds.size(0)
    acc = float(num_correct) / num_samples
    print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))

# %% [markdown]
# ### Check the accuracy of the model.
#
# Let's see the train and check_accuracy code in action -- feel free to use these methods when evaluating the models you develop below.
#
# You should get a training loss of around 1.0-1.2, and a validation accuracy of around 50-60%. As mentioned above, if you re-run the cells, you'll be training more epochs, so your performance will improve past these numbers.
#
# But don't worry about getting these numbers better -- this was just practice before you tackle designing your own model.

# %%
torch.random.manual_seed(12345)
fixed_model.cpu()
fixed_model.apply(reset) 
fixed_model.train() 
train(fixed_model, loss_fn, optimizer,image_dataloader_train, num_epochs=1) 
check_accuracy(fixed_model, image_dataloader_train)# check accuracy on the training set
# Out:
# Starting epoch 1 / 1
# C:\Users\Abhay Goyal\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   del sys.path[0]
# t = 100, loss = 2.2941
# t = 200, loss = 2.2571
# t = 300, loss = 2.1283
# t = 400, loss = 1.8297
# t = 500, loss = 1.7058
# t = 600, loss = 1.5227
# t = 700, loss = 1.4958
# Got 11852 / 23310 correct (50.85)

# %% [markdown]
# ### Don't forget the validation set!
#
# And note that you can use the check_accuracy function to evaluate on the validation set, by passing **image_dataloader_val** as the second argument to check_accuracy. The accuracy on validation set is arround 40-50%.

# %%
check_accuracy(fixed_model, image_dataloader_val)#check accuracy on the validation set
# Out:
# Got 3092 / 6690 correct (46.22)

# %% [markdown]
# ##### Train a better  model for action recognition!
#
# Now it's your job to experiment with architectures, hyperparameters, loss functions, and optimizers to train a model that achieves better accuracy on the action recognition **validation** set. You can use the check_accuracy and train functions from above.

# %% [markdown]
# ### Things you should try:
# - **Filter size**: Above we used 7x7; this makes pretty pictures but smaller filters may be more efficient
# - **Number of filters**: Do more or fewer do better?
# - **Pooling vs Strided Convolution**: Do you use max pooling or just stride convolutions?
# - **Batch normalization**: Try adding spatial batch normalization after convolution layers and vanilla batch normalization after affine layers. Do your networks train faster?
# - **Network architecture**: The network above has two layers of trainable parameters. Can you do better with a deep network? Good architectures to try include:
#     - [conv-relu-pool]xN -> [affine]xM -> [softmax or SVM]
#     - [conv-relu-conv-relu-pool]xN -> [affine]xM -> [softmax or SVM]
#     - [batchnorm-relu-conv]xN -> [affine]xM -> [softmax or SVM]
# - **Global Average Pooling**: Instead of flattening and then having multiple affine layers, perform convolutions until your image gets small (7x7 or so) and then perform an average pooling operation to get to a 1x1 image picture (1, 1 , Filter#), which is then reshaped into a (Filter#) vector. This is used in [Google's Inception Network](https://arxiv.org/abs/1512.00567) (See Table 1 for their architecture).
# - **Regularization**: Add l2 weight regularization, or perhaps use Dropout.
#
# ### Tips for training
# For each network architecture that you try, you should tune the learning rate and regularization strength. When doing this there are a couple important things to keep in mind:
#
# - If the parameters are working well, you should see improvement within a few hundred iterations
# - Remember the coarse-to-fine approach for hyperparameter tuning: start by testing a large range of hyperparameters for just a few training iterations to find the combinations of parameters that are working at all.
# - Once you have found some sets of parameters that seem to work, search more finely around these parameters. You may need to train for more epochs.
# - You should use the validation set for hyperparameter search, and save your test set for evaluating your architecture on the best parameters as selected by the validation set.
#
# ### Going above and beyond
# If you are feeling adventurous there are many other features you can implement to try and improve your performance. You are **not required** to implement any of these; however they would be good things to try.
#
# - Alternative update steps: For the assignment we implemented SGD+momentum, RMSprop, and Adam; you could try alternatives like AdaGrad or AdaDelta.
# - Alternative activation functions such as leaky ReLU, parametric ReLU, ELU, or MaxOut.
# - Model ensembles
# - Data augmentation
# - New Architectures
#   - [ResNets](https://arxiv.org/abs/1512.03385) where the input from the previous layer is added to the output.
#   - [DenseNets](https://arxiv.org/abs/1608.06993) where inputs into previous layers are concatenated together.
#   - [This blog has an in-depth overview](https://chatbotslife.com/resnets-highwaynets-and-densenets-oh-my-9bb15918ee32)
#
# If you do decide to implement something extra, clearly describe it in the "Extra Credit Description" cell below.
#
# ### What we expect
# At the very least, you should be able to train a ConvNet that gets at least 55% accuracy on the validation set. This is just a lower bound - if you are careful it should be possible to get accuracies much higher than that! Extra credit points will be awarded for particularly high-scoring models or unique approaches.
#
# You should use the space below to experiment and train your network.

# %%
###########3rd TODO (6 points, must submit the results to Kaggle) ##############
# Train your model here, and make sure the output of this cell is the accuracy of your best model on the 
# train, val, and test sets. Here's some code to get you started. The output of this cell should be the training
# and validation accuracy on your best model (measured by validation accuracy).

# model = None
fixed_model_base = nn.Sequential( 
                nn.Conv2d(3, 200, kernel_size=10, stride=3),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(3, stride = 1),
                nn.BatchNorm2d(200),
                nn.Dropout2d(0.1),
                nn.Conv2d(200, 100, kernel_size=5, stride=2),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(3, stride = 1),
                nn.BatchNorm2d(100),
                nn.Dropout2d(0.2),
                nn.Conv2d(100, 50, kernel_size=3, stride=1),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(2, stride=1),
                nn.BatchNorm2d(50),
                Flatten(),
                nn.Linear(200, 100),
                nn.Linear(100, 50),
                nn.Linear(50, 10),
                nn.LogSoftmax()
    ####################################
            )
model = fixed_model_base.type(dtype)

summary(model,(3,64,64))

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.RMSprop(model.parameters(), lr = 0.0001)
# optimizer = None
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 200, 19, 19]          60,200
#               ReLU-2          [-1, 200, 19, 19]               0
#          MaxPool2d-3          [-1, 200, 17, 17]               0
#        BatchNorm2d-4          [-1, 200, 17, 17]             400
#          Dropout2d-5          [-1, 200, 17, 17]               0
#             Conv2d-6            [-1, 100, 7, 7]         500,100
#               ReLU-7            [-1, 100, 7, 7]               0
#          MaxPool2d-8            [-1, 100, 5, 5]               0
#        BatchNorm2d-9            [-1, 100, 5, 5]             200
#         Dropout2d-10            [-1, 100, 5, 5]               0
#            Conv2d-11             [-1, 50, 3, 3]          45,050
#              ReLU-12             [-1, 50, 3, 3]               0
#         MaxPool2d-13             [-1, 50, 2, 2]               0
#       BatchNorm2d-14             [-1, 50, 2, 2]             100
#           Flatten-15                  [-1, 200]               0
#            Linear-16                  [-1, 100]          20,100
#            Linear-17                   [-1, 50]           5,050
#            Linear-18                   [-1, 10]             510
#        LogSoftmax-19                   [-1, 10]               0
# ================================================================
# Total params: 631,710
# Trainable params: 631,710
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 2.57
# Params size (MB): 2.41
# Estimated Total Size (MB): 5.03
# ----------------------------------------------------------------
# C:\Users\Abhay Goyal\Anaconda3\lib\site-packages\torch\nn\modules\container.py:91: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)

# %%
## Now we're going to feed a random batch into the model you defined and make sure the output is the right size
x = torch.randn(32, 3, 64, 64).type(dtype)
x_var = Variable(x.type(dtype)) # Construct a PyTorch Variable out of your input data
ans = model(x_var)        # Feed it through the model! 

# Check to make sure what comes out of your model
# is the right dimensionality... this should be True
# if you've done everything correctly
print(np.array(ans.size()))
np.array_equal(np.array(ans.size()), np.array([32, 10]))
# Out:
# [32 10]
# C:\Users\Abhay Goyal\Anaconda3\lib\site-packages\torch\nn\modules\container.py:91: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# True

# %%
torch.random.manual_seed(12345)
model.cpu()
model.apply(reset) 
model.train() 
train(model, loss_fn, optimizer,image_dataloader_train, num_epochs=4) 
check_accuracy(model, image_dataloader_train)# check accuracy on the training set
# Out:
# Starting epoch 1 / 5
# C:\Users\Abhay Goyal\Anaconda3\lib\site-packages\torch\nn\modules\container.py:91: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# C:\Users\Abhay Goyal\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   del sys.path[0]
# t = 100, loss = 1.5520
# t = 200, loss = 1.1972
# t = 300, loss = 1.0882
# t = 400, loss = 0.8006
# t = 500, loss = 0.7458
# t = 600, loss = 0.4742
# t = 700, loss = 0.5839
# Starting epoch 2 / 5
# t = 100, loss = 0.4193
# t = 200, loss = 0.2099
# t = 300, loss = 0.1143
# t = 400, loss = 0.1888
# t = 500, loss = 0.1912
# t = 600, loss = 0.2118
# t = 700, loss = 0.2587
# Starting epoch 3 / 5
# t = 100, loss = 0.1383
# t = 200, loss = 0.0960
# t = 300, loss = 0.0521
# t = 400, loss = 0.0507
# t = 500, loss = 0.0665
# t = 600, loss = 0.0714
# t = 700, loss = 0.1795
# Starting epoch 4 / 5
# t = 100, loss = 0.0362
# t = 200, loss = 0.0299
# t = 300, loss = 0.0922
# t = 400, loss = 0.0717
# t = 500, loss = 0.1488
# t = 600, loss = 0.0569
# t = 700, loss = 0.1150
# Starting epoch 5 / 5
# t = 100, loss = 0.0385
# t = 200, loss = 0.0337
# t = 300, loss = 0.0114
# t = 400, loss = 0.0420
# t = 500, loss = 0.1095
# t = 600, loss = 0.0401
# t = 700, loss = 0.0096
# Got 23143 / 23310 correct (99.28)

# %%
check_accuracy(model, image_dataloader_val)
# Out:
# C:\Users\Abhay Goyal\Anaconda3\lib\site-packages\torch\nn\modules\container.py:91: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Got 4134 / 6690 correct (61.79)

# %% [markdown]
# ### Describe what you did
#
# In the cell below you should write an explanation of what you did, any additional features that you implemented, and any visualizations or graphs that you make in the process of training and evaluating your network.

# %% [markdown]
# Tell us here!
# ###########4th TODO (4 points) ##############
# <br>
# I have used the following layers
# <br>
# 10x10 Convolution layer with 200 filters and stride 3
# <br>
# ReLU layer
# <br>
# 3x3 MaxPoolLayer with stride 1
# <br>
# BatchNormLayer with input 200
# <br>
# Dropout Layer sets layers to 0 with probability of 0.1
# <br>
# 5x5 Convolution Layer with 100 filters and stride 2
# <br>
# ReLU layer
# <br>
# 3x3 MaxPoolLayer with stride 1
# <br>
# BatchNormLayer with input 100
# <br>
# Dropout Layer sets layers to 0 with probability of 0.2
# <br>
# 3x3 Convolution Layer with 50 filters and stride 1
# <br>
# ReLU layer
# <br>
# 3x3 MaxPoolLayer with stride 1
# <br>
# BatchNormLayer with input 50
# <br>
# Flatten
# <br>
# Linear layer from input 200 to 100
# <br>
# Linear layer from input 100 to 50
# <br>
# Linear layer from input 50 to 10
# <br>
# Softmax function
# <br>

# %% [markdown]
# ### Testing the model and submit on Kaggle
# Testing the model on the testing set and save the results as a .csv file.
# Please submitted the results.csv file generated by predict_on_test() to Kaggle(https://www.kaggle.com/c/cse512springhw3) to see how well your network performs on the test set.
# #######5th TODO (submit the result to Kaggle, the highest 3 entries get extra 10 points )###############

# %%
def predict_on_test(model, loader):
    '''
    if loader.dataset.train:
        print('Checking accuracy on validation set')
    else:
        print('Checking accuracy on test set')  
    '''
    num_correct = 0
    num_samples = 0
    model.eval() # Put the model in test mode (the opposite of model.train(), essentially)
    results=open('results1.csv','w')
    count=0
    results.write('Id'+','+'Class'+'\n')
    for t, sample in enumerate(loader):
        x_var = Variable(sample['image'])
        scores = model(x_var)
        _, preds = scores.data.max(1)
        for i in range(len(preds)):
#             print(preds[i])
            results.write(str(count)+','+str(preds[i].item())+'\n')
            count+=1
    results.close()
    return count
    
count=predict_on_test(model, image_dataloader_test)
print(count)
# Out:
# C:\Users\Abhay Goyal\Anaconda3\lib\site-packages\torch\nn\modules\container.py:91: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(5)
# tensor(5)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(4)
# tensor(5)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(8)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(4)
# tensor(8)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(1)
# tensor(5)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(8)
# tensor(4)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(8)
# tensor(0)
# tensor(0)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(6)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(0)
# tensor(5)
# tensor(5)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(8)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(3)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(6)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(9)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(9)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(8)
# tensor(5)
# tensor(5)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(1)
# tensor(9)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(5)
# tensor(1)
# tensor(5)
# tensor(4)
# tensor(4)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(5)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(4)
# tensor(3)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(5)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(5)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(5)
# tensor(5)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(4)
# tensor(1)
# tensor(4)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(9)
# tensor(8)
# tensor(9)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(5)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(5)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(5)
# tensor(1)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(4)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(9)
# tensor(9)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(3)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(8)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(1)
# tensor(5)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(9)
# tensor(9)
# tensor(8)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(6)
# tensor(1)
# tensor(6)
# tensor(3)
# tensor(7)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(8)
# tensor(8)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(8)
# tensor(9)
# tensor(8)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(8)
# tensor(8)
# tensor(9)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(8)
# tensor(0)
# tensor(8)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(4)
# tensor(4)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(5)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(6)
# tensor(6)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(0)
# tensor(4)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(5)
# tensor(5)
# tensor(1)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(6)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(9)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(6)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(8)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(1)
# tensor(6)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(8)
# tensor(4)
# tensor(5)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(1)
# tensor(3)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(5)
# tensor(3)
# tensor(5)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(8)
# tensor(8)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(8)
# tensor(8)
# tensor(1)
# tensor(4)
# tensor(5)
# tensor(4)
# tensor(3)
# tensor(5)
# tensor(5)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(5)
# tensor(4)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(5)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(6)
# tensor(0)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(8)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(1)
# tensor(4)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(5)
# tensor(5)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(4)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(6)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(4)
# tensor(5)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(4)
# tensor(5)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(5)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(5)
# tensor(5)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(5)
# tensor(5)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(4)
# tensor(4)
# tensor(8)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(5)
# tensor(5)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(6)
# tensor(0)
# tensor(6)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(5)
# tensor(5)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(5)
# tensor(5)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(5)
# tensor(4)
# tensor(5)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(0)
# tensor(7)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(6)
# tensor(7)
# tensor(6)
# tensor(4)
# tensor(5)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(4)
# tensor(4)
# tensor(5)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(5)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(4)
# tensor(8)
# tensor(4)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(5)
# tensor(0)
# tensor(5)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(5)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(8)
# tensor(8)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(5)
# tensor(5)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(5)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(6)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(6)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(5)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(5)
# tensor(4)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(4)
# tensor(1)
# tensor(4)
# tensor(5)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(8)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(5)
# tensor(4)
# tensor(5)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(1)
# tensor(8)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(8)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(4)
# tensor(4)
# tensor(5)
# tensor(8)
# tensor(4)
# tensor(8)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(5)
# tensor(5)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(5)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(1)
# tensor(3)
# tensor(1)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(5)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(8)
# tensor(9)
# tensor(9)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(8)
# tensor(8)
# tensor(6)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(5)
# tensor(5)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(8)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(5)
# tensor(9)
# tensor(3)
# tensor(9)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(5)
# tensor(4)
# tensor(5)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(6)
# tensor(6)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(9)
# tensor(9)
# tensor(3)
# tensor(6)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(8)
# tensor(8)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(5)
# tensor(8)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(9)
# tensor(9)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(4)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(7)
# tensor(6)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(8)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(8)
# tensor(8)
# tensor(9)
# tensor(0)
# tensor(9)
# tensor(0)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(8)
# tensor(8)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(6)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(5)
# tensor(4)
# tensor(5)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(5)
# tensor(5)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(0)
# tensor(6)
# tensor(6)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(3)
# tensor(2)
# tensor(3)
# tensor(5)
# tensor(6)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(6)
# tensor(5)
# tensor(5)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(5)
# tensor(5)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(6)
# tensor(1)
# tensor(1)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(9)
# tensor(0)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(5)
# tensor(0)
# tensor(6)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(6)
# tensor(1)
# tensor(6)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(1)
# tensor(1)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(8)
# tensor(3)
# tensor(8)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(5)
# tensor(4)
# tensor(4)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(4)
# tensor(5)
# tensor(4)
# tensor(1)
# tensor(5)
# tensor(5)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(8)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(9)
# tensor(5)
# tensor(4)
# tensor(1)
# tensor(1)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(1)
# tensor(1)
# tensor(5)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(6)
# tensor(0)
# tensor(6)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(1)
# tensor(5)
# tensor(1)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(9)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(1)
# tensor(5)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(1)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(0)
# tensor(4)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(6)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(9)
# tensor(7)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(5)
# tensor(5)
# tensor(1)
# tensor(1)
# tensor(5)
# tensor(4)
# tensor(4)
# tensor(4)
# ...
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(5)
# tensor(4)
# tensor(4)
# tensor(0)
# tensor(0)
# tensor(6)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(9)
# tensor(9)
# tensor(8)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(5)
# tensor(7)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(5)
# tensor(4)
# tensor(5)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(5)
# tensor(5)
# tensor(4)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(4)
# tensor(5)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(5)
# tensor(5)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(1)
# tensor(1)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(5)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(7)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(5)
# tensor(4)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(1)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(8)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(6)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(5)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(5)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(5)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(5)
# tensor(4)
# tensor(5)
# tensor(5)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(8)
# tensor(9)
# tensor(8)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(2)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(5)
# tensor(4)
# tensor(4)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(8)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(6)
# tensor(4)
# tensor(5)
# tensor(4)
# tensor(9)
# tensor(9)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(1)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(5)
# tensor(5)
# tensor(1)
# tensor(8)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(6)
# tensor(7)
# tensor(6)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(1)
# tensor(8)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(5)
# tensor(5)
# tensor(6)
# tensor(8)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(3)
# tensor(8)
# tensor(9)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(5)
# tensor(5)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(5)
# tensor(5)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(9)
# tensor(9)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(9)
# tensor(8)
# tensor(9)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(5)
# tensor(7)
# tensor(5)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(5)
# tensor(4)
# tensor(4)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(5)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(0)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(5)
# tensor(3)
# tensor(5)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(5)
# tensor(4)
# tensor(5)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(5)
# tensor(5)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(0)
# tensor(9)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(4)
# tensor(4)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(8)
# tensor(1)
# tensor(9)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(5)
# tensor(5)
# tensor(8)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(4)
# tensor(8)
# tensor(7)
# tensor(3)
# tensor(2)
# tensor(1)
# tensor(4)
# tensor(1)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(6)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(5)
# tensor(1)
# tensor(1)
# tensor(5)
# tensor(4)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(4)
# tensor(5)
# tensor(4)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(0)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(5)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(2)
# tensor(7)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(5)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(5)
# tensor(5)
# tensor(7)
# tensor(3)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(7)
# tensor(6)
# tensor(7)
# tensor(7)
# tensor(5)
# tensor(8)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(5)
# tensor(5)
# tensor(5)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(5)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(5)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(6)
# tensor(6)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(7)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(8)
# tensor(3)
# tensor(9)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(7)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(8)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(9)
# tensor(9)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(9)
# tensor(9)
# tensor(9)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(4)
# tensor(5)
# tensor(4)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(1)
# tensor(1)
# tensor(4)
# tensor(4)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(8)
# tensor(8)
# tensor(8)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(5)
# tensor(4)
# tensor(4)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# tensor(7)
# 9810

# %% [markdown]
# ### GPU! (This part is optional, 0 points)
#
# If you have access to GPU, you can make the code run on GPU, it would be much faster.
#
# Now, we're going to switch the dtype of the model and our data to the GPU-friendly tensors, and see what happens... everything is the same, except we are casting our model and input tensors as this new dtype instead of the old one.
#
# If this returns false, or otherwise fails in a not-graceful way (i.e., with some error message), you may not have an NVIDIA GPU available on your machine.

# %%
# Verify that CUDA is properly configured and you have a GPU available

torch.cuda.is_available()
# Out:
# False

# %%
import copy
gpu_dtype = torch.cuda.FloatTensor

fixed_model_gpu = copy.deepcopy(fixed_model_base)#.type(gpu_dtype)
fixed_model_gpu.cuda()
x_gpu = torch.randn(4, 3, 64, 64).cuda()#.type(gpu_dtype)
x_var_gpu = Variable(x_gpu)#type(gpu_dtype)) # Construct a PyTorch Variable out of your input data
ans = fixed_model_gpu(x_var_gpu)        # Feed it through the model! 

# Check to make sure what comes out of your model
# is the right dimensionality... this should be True
# if you've done everything correctly
np.array_equal(np.array(ans.size()), np.array([4, 10]))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-50-391eeb4c98da> in <module>()
#       3
#       4 fixed_model_gpu = copy.deepcopy(fixed_model_base)#.type(gpu_dtype)
# ----> 5 fixed_model_gpu.cuda()
#       6 x_gpu = torch.randn(4, 3, 64, 64).cuda()#.type(gpu_dtype)
#       7 x_var_gpu = Variable(x_gpu)#type(gpu_dtype)) # Construct a PyTorch Variable out of your input data
#
# C:\Users\Abhay Goyal\Anaconda3\lib\site-packages\torch\nn\modules\module.py in cuda(self, device)
#     256             Module: self
#     257         """
# --> 258         return self._apply(lambda t: t.cuda(device))
#     259
#     260     def cpu(self):
#
# C:\Users\Abhay Goyal\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _apply(self, fn)
#     183     def _apply(self, fn):
#     184         for module in self.children():
# --> 185             module._apply(fn)
#     186
#     187         for param in self._parameters.values():
#
# C:\Users\Abhay Goyal\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _apply(self, fn)
#     189                 # Tensors stored in modules are graph leaves, and we don't
#     190                 # want to create copy nodes, so we have to unpack the data.
# --> 191                 param.data = fn(param.data)
#     192                 if param._grad is not None:
#     193                     param._grad.data = fn(param._grad.data)
#
# C:\Users\Abhay Goyal\Anaconda3\lib\site-packages\torch\nn\modules\module.py in <lambda>(t)
#     256             Module: self
#     257         """
# --> 258         return self._apply(lambda t: t.cuda(device))
#     259
#     260     def cpu(self):
#
# RuntimeError: Cannot initialize CUDA without ATen_cuda library. PyTorch splits its backend into two shared libraries: a CPU library and a CUDA library; this error has occurred because you are trying to use some CUDA functionality, but the CUDA library has not been loaded by the dynamic linker for some reason.  The CUDA library MUST be loaded, EVEN IF you don't directly use any symbols from the CUDA library! One common culprit is a lack of -Wl,--no-as-needed in your link arguments; many dynamic linkers will delete dynamic library dependencies if you don't depend on any of their symbols.  You can check if this has occurred by using ldd on your binary to see if there is a dependency on *_cuda.so library.

# %% [markdown]
# Run the following cell to evaluate the performance of the forward pass running on the CPU:

# %%
# %%timeit 
ans = fixed_model(x_var)

# %% [markdown]
# ... and now the GPU:

# %%
# %%timeit 
torch.cuda.synchronize() # Make sure there are no pending GPU computations
ans = fixed_model_gpu(x_var_gpu)        # Feed it through the model! 
torch.cuda.synchronize() # Make sure there are no pending GPU computations

# %% [markdown]
# You should observe that even a simple forward pass like this is significantly faster on the GPU. So for the rest of the assignment (and when you go train your models in assignment 3 and your project!), you should use the GPU datatype for your model and your tensors: as a reminder that is *torch.cuda.FloatTensor* (in our notebook here as *gpu_dtype*)

# %% [markdown]
# Let's make the loss function and training variables to GPU friendly format by '.cuda()'

# %%
loss_fn = nn.CrossEntropyLoss().cuda()
optimizer = optim.RMSprop(fixed_model_gpu.parameters(), lr=1e-4)

# %%
def train(model, loss_fn, optimizer, dataloader, num_epochs = 1):
    for epoch in range(num_epochs):
        print('Starting epoch %d / %d' % (epoch + 1, num_epochs))
        model.train()
        for t, sample in enumerate(dataloader):
            x_var = Variable(sample['image'].cuda())
            y_var = Variable(sample['Label'].cuda().long())

            scores = model(x_var)
            
            loss = loss_fn(scores, y_var)
            if (t + 1) % print_every == 0:
                print('t = %d, loss = %.4f' % (t + 1, loss.data[0]))

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

def check_accuracy(model, loader):
    '''
    if loader.dataset.train:
        print('Checking accuracy on validation set')
    else:
        print('Checking accuracy on test set')  
    '''
    num_correct = 0
    num_samples = 0
    model.eval() # Put the model in test mode (the opposite of model.train(), essentially)
    for t, sample in enumerate(loader):
        x_var = Variable(sample['image'].cuda())
        y_var = sample['Label'].cuda()
        y_var=y_var.cpu()
        scores = model(x_var)
        _, preds = scores.data.cpu().max(1)
        #print(preds)
        #print(y_var)
        num_correct += (preds.numpy() == y_var.numpy()).sum()
        num_samples += preds.size(0)
    acc = float(num_correct) / num_samples
    print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))

# %% [markdown]
# Run on GPU!

# %%
torch.cuda.random.manual_seed(12345)

fixed_model_gpu.apply(reset) 
fixed_model_gpu.train() 
train(fixed_model_gpu, loss_fn, optimizer,image_dataloader_train, num_epochs=1) 
check_accuracy(fixed_model_gpu, image_dataloader_train)# check accuracy on the training set

# %% [markdown]
# ### 3D Convolution on video clips (15 points+10 extra points)
# 3D convolution is for videos, it has one more dimension than 2d convolution. You can find the document for 3D convolution here http://pytorch.org/docs/master/nn.html#torch.nn.Conv3dIn. In our dataset, each clip is a video of 3 frames. Lets classify the each clip rather than each image using 3D convolution.
# We offer the data loader, the train_3d and check_accuracy

# %%
class ActionClipDataset(Dataset):
    """Action Landmarks dataset."""

    def __init__(self,  root_dir,labels=[], transform=None):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        
        self.root_dir = root_dir
        self.transform = transform
        self.length=len(os.listdir(self.root_dir))
        self.labels=labels

    def __len__(self):
        return self.length

    def __getitem__(self, idx):
        
        folder=idx+1
        folder=format(folder,'05d')
        clip=[]
        if len(self.labels)!=0:
            Label=self.labels[idx][0]-1
        for i in range(3):
            imidx=i+1
            imgname=str(imidx)+'.jpg'
            img_path = os.path.join(self.root_dir,
                                    folder,imgname)
            image = Image.open(img_path)
            image=np.array(image)
            clip.append(image)
        if self.transform:
            clip=np.asarray(clip)
            clip=np.transpose(clip, (0,3,1,2))
            clip = torch.from_numpy(np.asarray(clip))
        if len(self.labels)!=0:
            sample={'clip':clip,'Label':Label,'folder':folder}
        else:
            sample={'clip':clip,'folder':folder}
        return sample

clip_dataset=ActionClipDataset(root_dir='./data/trainClips/',\
                               labels=label_train,transform=T.ToTensor())#/home/tqvinh/Study/CSE512/cse512-s18/hw2data/trainClips/
for i in range(10):
    sample=clip_dataset[i]
    print(sample['clip'].shape)
    print(sample['Label'])
    print(sample['folder'])
# Out:
# torch.Size([3, 3, 64, 64])
# 0.0
# 00001
# torch.Size([3, 3, 64, 64])
# 0.0
# 00002
# torch.Size([3, 3, 64, 64])
# 0.0
# 00003
# torch.Size([3, 3, 64, 64])
# 0.0
# 00004
# torch.Size([3, 3, 64, 64])
# 0.0
# 00005
# torch.Size([3, 3, 64, 64])
# 0.0
# 00006
# torch.Size([3, 3, 64, 64])
# 0.0
# 00007
# torch.Size([3, 3, 64, 64])
# 0.0
# 00008
# torch.Size([3, 3, 64, 64])
# 0.0
# 00009
# torch.Size([3, 3, 64, 64])
# 0.0
# 00010

# %%
clip_dataloader = DataLoader(clip_dataset, batch_size=4,
                        shuffle=True, num_workers=0)


for i,sample in enumerate(clip_dataloader):
    print(i,sample['clip'].shape,sample['folder'],sample['Label'])
    if i>20: 
        break
# Out:
# 0 torch.Size([4, 3, 3, 64, 64]) ['05989', '03884', '04238', '07523'] tensor([7., 4., 5., 9.], dtype=torch.float64)
# 1 torch.Size([4, 3, 3, 64, 64]) ['01707', '05701', '02885', '03084'] tensor([1., 7., 3., 3.], dtype=torch.float64)
# 2 torch.Size([4, 3, 3, 64, 64]) ['05732', '05938', '02866', '06762'] tensor([7., 7., 3., 8.], dtype=torch.float64)
# 3 torch.Size([4, 3, 3, 64, 64]) ['00431', '04520', '06104', '04274'] tensor([0., 5., 7., 5.], dtype=torch.float64)
# 4 torch.Size([4, 3, 3, 64, 64]) ['03065', '07599', '00187', '04763'] tensor([3., 9., 0., 5.], dtype=torch.float64)
# 5 torch.Size([4, 3, 3, 64, 64]) ['02537', '01829', '06788', '03020'] tensor([2., 2., 8., 3.], dtype=torch.float64)
# 6 torch.Size([4, 3, 3, 64, 64]) ['02484', '01043', '01871', '00246'] tensor([2., 1., 2., 0.], dtype=torch.float64)
# 7 torch.Size([4, 3, 3, 64, 64]) ['01563', '03486', '04003', '03278'] tensor([1., 3., 4., 3.], dtype=torch.float64)
# 8 torch.Size([4, 3, 3, 64, 64]) ['03063', '03317', '03490', '02340'] tensor([3., 3., 3., 2.], dtype=torch.float64)
# 9 torch.Size([4, 3, 3, 64, 64]) ['00198', '03547', '02472', '01886'] tensor([0., 4., 2., 2.], dtype=torch.float64)
# 10 torch.Size([4, 3, 3, 64, 64]) ['06396', '00509', '02732', '04199'] tensor([7., 0., 3., 5.], dtype=torch.float64)
# 11 torch.Size([4, 3, 3, 64, 64]) ['00712', '07419', '01057', '03627'] tensor([0., 9., 1., 4.], dtype=torch.float64)
# 12 torch.Size([4, 3, 3, 64, 64]) ['00514', '02504', '01493', '00830'] tensor([0., 2., 1., 0.], dtype=torch.float64)
# 13 torch.Size([4, 3, 3, 64, 64]) ['01422', '07672', '04051', '04548'] tensor([1., 9., 4., 5.], dtype=torch.float64)
# 14 torch.Size([4, 3, 3, 64, 64]) ['02280', '00490', '03140', '04580'] tensor([2., 0., 3., 5.], dtype=torch.float64)
# 15 torch.Size([4, 3, 3, 64, 64]) ['04877', '04157', '02669', '02122'] tensor([5., 4., 2., 2.], dtype=torch.float64)
# 16 torch.Size([4, 3, 3, 64, 64]) ['03921', '06181', '06577', '04041'] tensor([4., 7., 8., 4.], dtype=torch.float64)
# 17 torch.Size([4, 3, 3, 64, 64]) ['04848', '03640', '00084', '04705'] tensor([5., 4., 0., 5.], dtype=torch.float64)
# 18 torch.Size([4, 3, 3, 64, 64]) ['06231', '00343', '02786', '04234'] tensor([7., 0., 3., 5.], dtype=torch.float64)
# 19 torch.Size([4, 3, 3, 64, 64]) ['04843', '06229', '04833', '03985'] tensor([5., 7., 5., 4.], dtype=torch.float64)
# 20 torch.Size([4, 3, 3, 64, 64]) ['06128', '00749', '06531', '07275'] tensor([7., 0., 8., 9.], dtype=torch.float64)
# 21 torch.Size([4, 3, 3, 64, 64]) ['07386', '03064', '05136', '01942'] tensor([9., 3., 6., 2.], dtype=torch.float64)

# %%
clip_dataset_train=ActionClipDataset(root_dir='./data/trainClips/',labels=label_train,transform=T.ToTensor())

clip_dataloader_train = DataLoader(clip_dataset_train, batch_size=16,
                        shuffle=True, num_workers=0)
clip_dataset_val=ActionClipDataset(root_dir='./data/valClips/',labels=label_val,transform=T.ToTensor())

clip_dataloader_val = DataLoader(clip_dataset_val, batch_size=16,
                        shuffle=True, num_workers=0)
clip_dataset_test=ActionClipDataset(root_dir='./data/testClips/',labels=[],transform=T.ToTensor())

clip_dataloader_test = DataLoader(clip_dataset_test, batch_size=16,
                        shuffle=False, num_workers=0)

# %% [markdown]
# Write the Flatten for 3d covolution feature maps.

# %%
class Flatten3d(nn.Module):
    def forward(self, x):
        ###############6th TODO (3 points)###################
        N, C, D, H, W = x.size()
        return(x.view(N,-1))
        
# print(x.size())

# %% [markdown]
# Design a network using 3D convolution on videos for video classification.

# %%
fixed_model_3d = nn.Sequential( # You fill this in!
    ###############7th TODO (8 points)#########################
        nn.Conv3d(in_channels = 3, out_channels = 50, kernel_size=2, stride=1),
        nn.ReLU(inplace=True),
        nn.MaxPool3d((1,2,2), stride = 2),
        nn.Conv3d(in_channels = 50, out_channels = 100, kernel_size=(1,3,3), stride=1),
        nn.ReLU(inplace = True),
        nn.MaxPool3d((1,3,3), stride=2),
        nn.Dropout3d(0.1),
        Flatten3d(),
        nn.ReLU(inplace=True),
        nn.Linear(19600,10),
        nn.LogSoftmax()
)

fixed_model_3d = fixed_model_3d.type(dtype)
x = torch.randn(32,3, 3, 64, 64).type(dtype)
x_var = Variable(x).type(dtype) # Construct a PyTorch Variable out of your input data
ans = fixed_model_3d(x_var) 
np.array_equal(np.array(ans.size()), np.array([32, 10]))

# summary(fixed_model_3d, input_size=(3,2,50,2))
# Out:
# C:\Users\Abhay Goyal\Anaconda3\lib\site-packages\torch\nn\modules\container.py:91: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# True

# %% [markdown]
# ### Describe what you did (4 points)
#
# In the cell below you should write an explanation of what you did, any additional features that you implemented, and any visualizations or graphs that you make in the process of training and evaluating your network.

# %% [markdown]
# ### 8th TODO Tell us here:
# <br>
# 2x2x2 Conv3d layer with 3 input channels mapped to 50 output channels with stride 1
# <br>
# ReLU layer
# <br>
# MaxPoolLayer with stride 2 and window 1x2x2
# <br>
# 1x3x3 Conv3d layer with 50 input channels mapped to 100 output channels with stride 1
# <br>
# ReLU layer
# <br>
# MaxPoolLayer with stride 2 and window 1x3x3
# <br>
# DropOut layer with probability 0.1
# <br>
# Flatten layer
# <br>
# ReLU layer
# <br>
# Linear layer to convert to 10 categories
# <br>
# Softmax layer
# <br>

# %%
loss_fn = nn.CrossEntropyLoss().type(dtype)
optimizer = optim.RMSprop(fixed_model_3d.parameters(), lr=1e-4)

# %%
def train_3d(model, loss_fn, optimizer,dataloader,num_epochs = 1):
    for epoch in range(num_epochs):
        print('Starting epoch %d / %d' % (epoch + 1, num_epochs))
        model.train()
        for t, sample in enumerate(dataloader):
            x_var = Variable(sample['clip'].type(dtype))
            y_var = Variable(sample['Label'].type(dtype).long())

            scores = model(x_var)
            
            loss = loss_fn(scores, y_var)
            if (t + 1) % print_every == 0:
                print('t = %d, loss = %.4f' % (t + 1, loss.data[0]))

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

def check_accuracy_3d(model, loader):
    '''
    if loader.dataset.train:
        print('Checking accuracy on validation set')
    else:
        print('Checking accuracy on test set')  
    '''
    num_correct = 0
    num_samples = 0
    model.eval() # Put the model in test mode (the opposite of model.train(), essentially)
    for t, sample in enumerate(loader):
        x_var = Variable(sample['clip'].type(dtype))
        y_var = sample['Label'].type(dtype)
        y_var=y_var.cpu()
        scores = model(x_var)
        _, preds = scores.data.cpu().max(1)
        #print(preds)
        #print(y_var)
        num_correct += (preds.numpy() == y_var.numpy()).sum()
        num_samples += preds.size(0)
    acc = float(num_correct) / num_samples
    print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))

# %%
torch.random.manual_seed(12345)
fixed_model_3d.apply(reset) 
fixed_model_3d.train() 
train_3d(fixed_model_3d, loss_fn, optimizer,clip_dataloader_train, num_epochs=2) 
fixed_model_3d.eval() 
check_accuracy_3d(fixed_model_3d, clip_dataloader_train)
check_accuracy_3d(fixed_model_3d, clip_dataloader_val)
# Out:
# Starting epoch 1 / 2
# C:\Users\Abhay Goyal\Anaconda3\lib\site-packages\torch\nn\modules\container.py:91: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# C:\Users\Abhay Goyal\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   del sys.path[0]
# t = 100, loss = 1.4507
# t = 200, loss = 0.9612
# t = 300, loss = 1.0649
# t = 400, loss = 0.4448
# Starting epoch 2 / 2
# t = 100, loss = 0.2551
# t = 200, loss = 0.1736
# t = 300, loss = 0.4258
# t = 400, loss = 0.0668
# Got 7613 / 7770 correct (97.98)
# Got 1400 / 2230 correct (62.78)

# %%
check_accuracy_3d(fixed_model_3d, clip_dataloader_val)
# Out:
# C:\Users\Abhay Goyal\Anaconda3\lib\site-packages\torch\nn\modules\container.py:91: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Got 1400 / 2230 correct (62.78)

# %% [markdown]
# Test your 3d convolution model on the validation set. You don't need to submit the result of this part to kaggle.

# %% [markdown]
# Test your model on the test set, predict_on_test_3d() will generate a file named 'results_3d.csv'. Please submit the csv file to kaggle https://www.kaggle.com/c/cse512springhw3video
# The highest 3 entries get extra 10 points.

# %%
def predict_on_test_3d(model, loader):
    '''
    if loader.dataset.train:
        print('Checking accuracy on validation set')
    else:
        print('Checking accuracy on test set')  
    '''
    num_correct = 0
    num_samples = 0
    model.eval() # Put the model in test mode (the opposite of model.train(), essentially)
    results=open('results_3d.csv','w')
    count=0
    results.write('Id'+','+'Class'+'\n')
    for t, sample in enumerate(loader):
        x_var = Variable(sample['clip'].type(dtype))
        scores = model(x_var)
        _, preds = scores.data.max(1)
        for i in range(len(preds)):
            results.write(str(count)+','+str(preds[i].item())+'\n')
            count+=1
    results.close()
    return count
    
count=predict_on_test_3d(fixed_model_3d, clip_dataloader_test)
print(count)
# Out:
# C:\Users\Abhay Goyal\Anaconda3\lib\site-packages\torch\nn\modules\container.py:91: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# 3270
